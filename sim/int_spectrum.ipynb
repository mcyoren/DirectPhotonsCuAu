# %%
# %run ../real/input/Format.ipynb
import numpy as np
import pandas as pd
import ROOT as root

root.gStyle.SetOptStat(0)
root.TH1.AddDirectory(False)

# %jsroot on
# Out:
# /home/yoren/.local/lib/python3.10/site-packages/nbformat/__init__.py:96: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# Welcome to JupyROOT 6.30/06

# %%
safe_as_pdf = True
draw_logo = True

# %%
df_mb = pd.read_csv("output/final_integrated/cuau_mb_direct_gamma_dndy_1_5.csv")
df_mb
# Out:
#   system             label  pt_min  pt_max   dNch  dNch_err      dNdy  \
# 0   CuAu  This analysis MB     1.0     5.0  100.0      12.0  0.212813
#
#    dNdy_stat  dNdy_syst_down  dNdy_syst_up
# 0   0.026829        0.090448      0.090456

# %%
df_mb15 = pd.read_csv("output/final_integrated/cuau_mb_direct_gamma_dndy_15_5.csv")
df_mb15
# Out:
#   system             label  pt_min  pt_max   dNch  dNch_err      dNdy  \
# 0   CuAu  This analysis MB     1.5     5.0  100.0      12.0  0.063147
#
#    dNdy_stat  dNdy_syst_down  dNdy_syst_up
# 0   0.007567        0.022084      0.022092

# %%
dNch_mb = float(df_mb.loc[0, "dNch"])
dNch_mb_err = float(df_mb.loc[0, "dNch_err"])

dndy_mb = float(df_mb.loc[0, "dNdy"])
dndy_mb_stat = float(df_mb.loc[0, "dNdy_stat"])
dndy_mb_syst_down = float(df_mb.loc[0, "dNdy_syst_down"])
dndy_mb_syst_up = float(df_mb.loc[0, "dNdy_syst_up"])

pt_min = float(df_mb.loc[0, "pt_min"])
pt_max = float(df_mb.loc[0, "pt_max"])

print("MB point")
print("pT range:", pt_min, pt_max)
print("dNch =", dNch_mb, "+/-", dNch_mb_err)
print("dNdy =", dndy_mb, "+", dndy_mb_stat, "stat")
print("syst -/+", dndy_mb_syst_down, dndy_mb_syst_up)
# Out:
# MB point
# pT range: 1.0 5.0
# dNch = 100.0 +/- 12.0
# dNdy = 0.2128129709466284 + 0.0268286387336881 stat
# syst -/+ 0.0904484327011411 0.0904563793498664

# %%
Nch_ref = np.array([
    341.175, 151.75, 131.525,
    104.264,
    109.263, 51.654,
    519.025, 225.425, 85.475, 16.362,
    519.025, 225.425, 186.11,
    1206.75
])

eNch_ref = np.array([
    29.325, 12.69, 11.152,
    8.882,
    7.813, 3.559,
    26.25, 13.175, 8.075, 2.8137,
    26.25, 13.175, 11.324,
    45.75
])

Yield_ref = np.array([
    1.28873, 0.415701, 0.336163,
    0.259703,
    0.152438, 0.0608154,
    1.66115, 0.707725, 0.217113, 0.0229508,
    1.68592, 0.698072, 0.554999,
    4.75833
])

eYield_ref = np.array([
    0.271747, 0.115494, 0.0652705,
    0.110752,
    0.0597752, 0.0212248,
    0.202514, 0.0863305, 0.0329216, 0.00620148,
    0.231152, 0.0854467, 0.050432,
    0.316776
])

sYield_ref = np.array([
    0.452504, 0.210051, 0.172416,
    0.2140941,
    0.0691723, 0.0252199,
    0.5339347, 0.2478384, 0.0936435, 0.0154706,
    0.37753, 0.149428, 0.117674,
    1.87478
])

# %%
# Group indices for Archive / ScalingData.h, 1 < pT < 5 GeV/c
groups_1_5 = [
    {
        "name": "PHENIX Au+Au 200 GeV 2015",
        "idx": [6, 7, 8, 9],
        "color": root.kRed,
        "marker": 21,   # filled square
        "filled": True,
    },
    {
        "name": "PHENIX Au+Au 200 GeV 2015",
        "idx": [10, 11, 12],
        "color": root.kRed,
        "marker": 25,   # open square
        "filled": False,
    },
    {
        "name": "PHENIX Au+Au 62.4 GeV",
        "idx": [0, 1, 2],
        "color": root.kBlue,
        "marker": 20,   # filled circle
        "filled": True,
    },
    {
        "name": "PHENIX Au+Au 39 GeV",
        "idx": [3],
        "color": root.kOrange + 7,
        "marker": 24,   # open circle
        "filled": False,
    },
    {
        "name": "PHENIX Cu+Cu 200 GeV",
        "idx": [4, 5],
        "color": root.kGreen + 2,
        "marker": 22,   # filled triangle
        "filled": True,
    },
    {
        "name": "ALICE Pb+Pb 2760 GeV",
        "idx": [13],
        "color": root.kOrange + 1,
        "marker": 33,   # diamond/star-like
        "filled": False,
    },
]

# %%
groups_15_5 = [
    {
        "name": "PHENIX Au+Au 200 GeV 2015",
        "idx": [4, 5, 6, 7],
        "color": root.kRed,
        "marker": 21,
        "filled": True,
    },
    {
        "name": "PHENIX Au+Au 200 GeV 2015",
        "idx": [8, 9, 10],
        "color": root.kRed,
        "marker": 25,
        "filled": False,
    },
    {
        "name": "PHENIX Au+Au 62.4 GeV",
        "idx": [0, 1],
        "color": root.kBlue,
        "marker": 20,
        "filled": True,
    },
    {
        "name": "PHENIX Cu+Cu 200 GeV",
        "idx": [2, 3],
        "color": root.kGreen + 2,
        "marker": 22,
        "filled": True,
    },
    {
        "name": "ALICE Pb+Pb 2760 GeV",
        "idx": [11, 12],
        "color": root.kOrange + 1,
        "marker": 33,
        "filled": False,
    },
]

# %%
# Extra PHENIX Au+Au 200 GeV PPG / published points
# Direct gamma dN/dy, 1 < pT < 5 GeV/c

dNch_auau_ppg = np.array([
    623.9, 414.2, 274.0, 176.8,
    109.4, 61.6, 32.0, 15.5
])

# If you do not have dNch systematic/errors for these,
# use 5% as in the archive plotting macro.
dNch_auau_ppg_err = 0.05 * dNch_auau_ppg

y_auau_ppg = np.array([
    1.250e+00, 9.956e-01, 7.202e-01, 4.549e-01,
    2.626e-01, 1.358e-01, 5.746e-02, 2.700e-02
])

y_auau_ppg_stat = np.array([
    1.594e-01, 8.483e-02, 3.902e-02, 2.554e-02,
    1.433e-02, 7.254e-03, 3.696e-03, 1.880e-03
])

y_auau_ppg_syst = np.array([
    5.212e-01, 3.510e-01, 2.360e-01, 1.556e-01,
    9.418e-02, 5.193e-02, 2.455e-02, 1.054e-02
])

# %%
def make_standalone_reference_graphs(x, ex, y, ey_stat, ey_syst, name):
    g_stat = root.TGraphErrors(len(x))
    g_syst = root.TGraphErrors(len(x))

    for i in range(len(x)):
        g_stat.SetPoint(i, float(x[i]), float(y[i]))
        g_stat.SetPointError(i, 0.0, float(ey_stat[i]))

        g_syst.SetPoint(i, float(x[i]), float(y[i]))
        g_syst.SetPointError(i, float(ex[i]), float(ey_syst[i]))

    g_stat.SetName(f"g_{name}_stat")
    g_syst.SetName(f"g_{name}_syst")

    return g_stat, g_syst

# %%
g_auau_ppg_stat, g_auau_ppg_syst = make_standalone_reference_graphs(
    dNch_auau_ppg,
    dNch_auau_ppg_err,
    y_auau_ppg,
    y_auau_ppg_stat,
    y_auau_ppg_syst,
    "auau_ppg_200"
)

# Style: published Au+Au 200 as open red squares
g_auau_ppg_stat.SetMarkerStyle(25)
g_auau_ppg_stat.SetMarkerSize(1.2)
g_auau_ppg_stat.SetMarkerColor(root.kRed)
g_auau_ppg_stat.SetLineColor(root.kRed)

g_auau_ppg_syst.SetFillColorAlpha(root.kRed, 0.22)
g_auau_ppg_syst.SetLineColor(root.kRed)

# %%
def make_group_graphs(Nch, eNch, Y, eY, sY, group, name):
    idx = group["idx"]
    n = len(idx)

    g_stat = root.TGraphErrors(n)
    g_syst = root.TGraphErrors(n)

    for ip, i in enumerate(idx):
        x = float(Nch[i])
        y = float(Y[i])

        # stat: y stat only
        g_stat.SetPoint(ip, x, y)
        g_stat.SetPointError(ip, 0.0, float(eY[i]))

        # syst: x syst + y syst box
        ex_syst = max(0.05 * x, float(eNch[i]))
        g_syst.SetPoint(ip, x, y)
        g_syst.SetPointError(ip, ex_syst, float(sY[i]))

    g_stat.SetName(f"g_stat_{name}")
    g_syst.SetName(f"g_syst_{name}")

    color = group["color"]
    marker = group["marker"]

    g_stat.SetMarkerStyle(marker)
    g_stat.SetMarkerSize(1.15)
    g_stat.SetMarkerColor(color)
    g_stat.SetLineColor(color)

    # open marker style already controls open/filled for ROOT marker codes
    if not group["filled"]:
        g_stat.SetMarkerColor(color)
        g_stat.SetLineColor(color)

    g_syst.SetFillColorAlpha(color, 0.25)
    g_syst.SetLineColor(color)

    return g_stat, g_syst

# %%
def make_mb_graphs(dNch, dNch_err, dndy, stat, syst_down, syst_up):
    g_stat = root.TGraphErrors(1)
    g_syst = root.TGraphAsymmErrors(1)

    g_stat.SetName("g_mb_stat")
    g_syst.SetName("g_mb_syst")

    # stat point
    g_stat.SetPoint(0, float(dNch), float(dndy))
    g_stat.SetPointError(0, 0.0, float(stat))

    # syst box: x error is dNch uncertainty, y error is asymmetric syst
    g_syst.SetPoint(0, float(dNch), float(dndy))
    g_syst.SetPointError(
        0,
        float(dNch_err), float(dNch_err),
        float(syst_down), float(syst_up)
    )

    return g_stat, g_syst

# %%
g_mb_stat, g_mb_syst = make_mb_graphs(
    dNch_mb,
    dNch_mb_err,
    dndy_mb,
    dndy_mb_stat,
    dndy_mb_syst_down,
    dndy_mb_syst_up
)

# %%
groups_to_plot = groups_1_5
#groups_to_plot = groups_15_5

# %%
ref_graphs = []

for ig, group in enumerate(groups_to_plot):
    g_stat, g_syst = make_group_graphs(
        Nch_ref,
        eNch_ref,
        Yield_ref,
        eYield_ref,
        sYield_ref,
        group,
        f"group{ig}"
    )

    ref_graphs.append({
        "group": group,
        "stat": g_stat,
        "syst": g_syst,
    })

# %%
pt_label = f"{pt_min:g}<p_{{T}}<{pt_max:g} GeV/c"

c_dndy_vs_dNch = root.TCanvas("c_dndy_vs_dNch", "c_dndy_vs_dNch", 850, 700)
c_dndy_vs_dNch.SetLogy()
c_dndy_vs_dNch.SetLogx()

frame = root.TH2F(
    "frame_dndy_vs_dNch",
    f";dN_{{ch}}/d#eta;dN_{{#gamma}}^{{dir}}/dy, {pt_label}",
    100, 9.0, 2e3,
    100, 1e-4, 20.0
)
frame.SetStats(0)

Format_Hist_total(frame, title_x="dN_{ch}/d#eta",  title_y="dN_{#gamma}^{dir}/dy", left=0.15, bottom=0.15, right=0.01, top=0.01,  Tsize=0.06,  Lsize=0.06,\
                      Mstyle=21,  Msize=1.2, Mcolor=4,  Lwidth=3,  Lcolor=4,  offset_x=1.2, offset_y=1.2, title="",  Malpha=0.5,  Lalpha=1)
frame.Draw()

# Draw systematic boxes first
for item in ref_graphs:
    item["syst"].Draw("2 same")

# Draw stat markers second
for item in ref_graphs:
    item["stat"].Draw("P same")

#new auau 
# Extra PPG Au+Au 200 systematic boxes
g_auau_ppg_syst.Draw("2 same")
g_auau_ppg_stat.Draw("P same")

# Your MB syst
g_mb_syst.SetFillColorAlpha(root.kBlack, 0.60)
g_mb_syst.SetLineColor(root.kBlack)
g_mb_syst.Draw("2 same")

# Your MB stat
g_mb_stat.SetMarkerStyle(33)
g_mb_stat.SetMarkerSize(3.0)
g_mb_stat.SetMarkerColor(root.kBlack)
g_mb_stat.SetLineColor(root.kBlack)
g_mb_stat.Draw("P same")

# Legend similar to published plot
leg = root.TLegend(0.34, 0.18, 0.8, 0.5)
leg.SetBorderSize(0)
leg.SetFillStyle(0)
leg.SetTextSize(0.050)

# Avoid duplicate legend entries for Au+Au 200 if filled/open are both present
added = set()

leg.AddEntry(g_auau_ppg_stat, "PHENIX Au+Au 200 GeV 2025", "p")

for item in ref_graphs:
    name = item["group"]["name"]
    if name in added:
        continue
    leg.AddEntry(item["stat"], name, "p")
    added.add(name)

#leg.AddEntry(g_mb_syst, "Cu+Au MB syst.", "f")

leg.Draw()

# Optional label like the plot
leg0 = root.TLegend(0.18, 0.75, 0.58, 0.96, f"     Direct #gamma ({pt_label})")
leg0.SetBorderSize(0)
leg0.SetFillStyle(0)
leg0.SetTextSize(0.05)
leg0.AddEntry(g_mb_stat, "0%-93% Cu+Au 200 GeV", "p")

f_scale = root.TF1("f_scale", "[0]*pow(x,[1])", 10.0, 1500.0)
f_scale.SetParameters(1e-4, 1.25)
f_scale.SetLineColor(root.kBlack)
f_scale.SetLineStyle(2)
f_scale.SetLineWidth(2)
f_scale_copy = root.TF1("f_scale_copy", "[0]*pow(x,[1])", 10.0, 1500.0)
f_scale_copy.SetParameters(1e-4, 1.25)
f_scale_copy.SetLineColor(root.kBlack)
f_scale_copy.SetLineStyle(6)
f_scale_copy.SetLineWidth(2)


# Fit using all archive reference points
g_all_fit = root.TGraphErrors(len(Nch_ref))
for i in range(len(Nch_ref)):
    g_all_fit.SetPoint(i, float(Nch_ref[i]), float(Yield_ref[i]))
    g_all_fit.SetPointError(i, 0.0, float(eYield_ref[i]))

g_all_fit.Fit(f_scale, "RQ0")
#f_scale.Draw("same")

g_auau_ppg_stat.Fit(f_scale_copy, "RQ0")
f_scale_copy.Draw("same")
leg0.AddEntry(f_scale_copy, f"#alpha^{{2025}}_{{Au+Au}} = {f_scale_copy.GetParameter(1):.2f}", "l")
#leg0.AddEntry(f_scale_copy, f"#alpha^{{2025}}_{{Au+Au}} = {f_scale_copy.GetParameter(1):.2f} #pm {f_scale_copy.GetParError(1):.2f}", "l")
#leg0.AddEntry(f_scale, f"   #alpha_{{All}} = {f_scale.GetParameter(1):.2f} #pm {f_scale.GetParError(1):.2f}", "l")
leg0.Draw()


leg2 = root.TLegend(0.6, 0.5, 0.8, 0.56,"PRC109 044912")
leg2.SetBorderSize(0)
leg2.SetFillStyle(0)
leg2.SetTextSize(0.040)
leg2.Draw()

if draw_logo: root.PHENIXTools.DrawPreliminary(0.7, 0.57, 0.23) 

c_dndy_vs_dNch.Draw()

if safe_as_pdf: c_dndy_vs_dNch.SaveAs("output/res/dndy_vs_dNch_logo.pdf")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c_dndy_vs_dNch
# Info in <TCanvas::Print>: pdf file output/res/dndy_vs_dNch_logo.pdf has been created

# %%
import numpy as np
import ROOT as root

# ------------------------------------------------------------
# p+p direct photon fit from PRC 109, 044912
#
# d^3N / d^2pT dy = A_pp / (1 + (pT/p0)^2)^n
#
# This is the invariant yield:
# (1 / 2pi pT) d^2N / dpT dy
# ------------------------------------------------------------

A_pp = 1.60e-4   # (GeV/c)^-2
p0_pp = 1.45     # GeV/c
n_pp = 3.3

def pp_invariant_yield(pt, A=A_pp, p0=p0_pp, n=n_pp):
    pt = np.asarray(pt, dtype=float)
    return A / (1.0 + (pt / p0)**2)**n


def integrate_pp_yield(pt_min=1.0, pt_max=5.0, n_steps=20000):
    """
    Returns dN_gamma^dir/dy in p+p for pt_min < pT < pt_max.
    """
    pt = np.linspace(pt_min, pt_max, n_steps)
    inv = pp_invariant_yield(pt)

    # dN/dy = integral 2*pi*pT * invariant_yield dpT
    integrand = 2.0 * np.pi * pt * inv

    return np.trapz(integrand, pt)


Ypp_1_5 = integrate_pp_yield(1.0, 5.0)
print("Integrated p+p direct photon yield, 1<pT<5:", Ypp_1_5)


# ------------------------------------------------------------
# Ncoll vs dNch/deta table from PHENIX direct photon paper
# Use this to build a smooth Ncoll(dNch/deta) interpolation/fit.
# ------------------------------------------------------------

dNch_tab = np.array([
    519.2, 225.4, 85.5, 16.4,
    623.9, 414.2, 274.0, 176.8, 109.4, 61.6, 32.0, 16.0, 7.0
], dtype=float)

dNch_err_tab = np.array([
    26.3, 13.2, 8.0, 2.8,
    32.2, 20.2, 14.8, 11.6, 9.1, 7.1, 5.0, 4.0, 2.0
], dtype=float)

Ncoll_tab = np.array([
    770.6, 282.4, 82.6, 12.1,
    951.0, 590.1, 357.2, 207.5, 111.1, 54.1, 24.0, 10.0, 4.0
], dtype=float)

Ncoll_err_tab = np.array([
    79.9, 28.4, 9.3, 3.1,
    98.5, 61.1, 35.5, 21.2, 10.8, 7.9, 6.0, 3.0, 1.0
], dtype=float)


# ------------------------------------------------------------
# Fit Ncoll(dNch/deta) as power law:
# Ncoll = C * (dNch/deta)^beta
#
# This is only for drawing a smooth band.
# ------------------------------------------------------------

x = dNch_tab
y = Ncoll_tab

mask = np.isfinite(x) & np.isfinite(y) & (x > 0) & (y > 0)

logx = np.log(x[mask])
logy = np.log(y[mask])

# log Ncoll = beta * log(dNch) + logC
coeff, cov = np.polyfit(logx, logy, deg=1, cov=True)

beta_ncoll = coeff[0]
logC_ncoll = coeff[1]
C_ncoll = np.exp(logC_ncoll)

print("Ncoll fit:")
print("  C    =", C_ncoll)
print("  beta =", beta_ncoll)


def Ncoll_from_dNch(dnch):
    dnch = np.asarray(dnch, dtype=float)
    return C_ncoll * dnch**beta_ncoll


def rel_unc_Ncoll_fit(dnch):
    """
    Approximate uncertainty from the covariance of the log-log fit.
    """
    dnch = np.asarray(dnch, dtype=float)
    lx = np.log(dnch)

    # coeff order is [beta, logC]
    # Var(logN) = [logx, 1] cov [logx, 1]^T
    var_logN = (
        cov[0, 0] * lx**2
        + 2.0 * cov[0, 1] * lx
        + cov[1, 1]
    )

    var_logN = np.maximum(var_logN, 0.0)
    return np.sqrt(var_logN)


# ------------------------------------------------------------
# Uncertainty on p+p integrated yield.
#
# The paper band includes uncertainty from the p+p fit and low-pT
# extrapolation. If you later digitize the purple band, replace this
# with the digitized relative uncertainty.
# ------------------------------------------------------------

pp_int_rel_unc = 0.45  # choose 25% as starting value; tune to match paper band

# Optional extra Ncoll normalization uncertainty.
# Set to 0 if you want only fit-band uncertainty.
Ncoll_extra_rel_unc = 0.0


# ------------------------------------------------------------
# Build ROOT graphs: central line + uncertainty band
# ------------------------------------------------------------

xmin = 10.0
xmax = 700.0
npts = 300

xgrid = np.logspace(np.log10(xmin), np.log10(xmax), npts)

Ncoll_grid = Ncoll_from_dNch(xgrid)
ygrid = Ypp_1_5 * Ncoll_grid

rel_ncoll_fit = rel_unc_Ncoll_fit(xgrid)

rel_total = np.sqrt(
    pp_int_rel_unc**2
    + rel_ncoll_fit**2
    + Ncoll_extra_rel_unc**2
)

g_pp_ncoll_scaled = root.TGraph(npts)
g_pp_ncoll_scaled_band = root.TGraphAsymmErrors(npts)

for i in range(npts):
    xx = float(xgrid[i])
    yy = float(ygrid[i])
    ey = float(yy * rel_total[i])

    g_pp_ncoll_scaled.SetPoint(i, xx, yy)

    g_pp_ncoll_scaled_band.SetPoint(i, xx, yy)
    g_pp_ncoll_scaled_band.SetPointError(i, 0.0, 0.0, ey, ey)

g_pp_ncoll_scaled.SetName("g_pp_ncoll_scaled")
g_pp_ncoll_scaled_band.SetName("g_pp_ncoll_scaled_band")

# Style similar to PHENIX purple band
g_pp_ncoll_scaled.SetLineColor(root.kMagenta + 1)
g_pp_ncoll_scaled.SetLineWidth(3)
g_pp_ncoll_scaled.SetFillColorAlpha(root.kMagenta + 1, 0.30)

g_pp_ncoll_scaled_band.SetFillColorAlpha(root.kMagenta + 1, 0.30)
g_pp_ncoll_scaled_band.SetLineColor(root.kMagenta + 1)
g_pp_ncoll_scaled_band.SetLineWidth(1)


# ------------------------------------------------------------
# Draw example:
# Draw this after the frame, before data points.
# ------------------------------------------------------------

# g_pp_ncoll_scaled_band.Draw("3 same")
# g_pp_ncoll_scaled.Draw("L same")
# Out:
# Integrated p+p direct photon yield, 1<pT<5: 0.00018648899899423915
# Ncoll fit:
#   C    = 0.3559691071898167
#   beta = 1.2278090299994489

# %%
pt_label = f"{pt_min:g}<p_{{T}}<{pt_max:g} GeV/c"

c_dndy_vs_dNch = root.TCanvas("c_dndy_vs_dNch", "c_dndy_vs_dNch", 850, 700)
c_dndy_vs_dNch.SetLogy()
c_dndy_vs_dNch.SetLogx()

frame = root.TH2F(
    "frame_dndy_vs_dNch",
    f";dN_{{ch}}/d#eta;dN_{{#gamma}}^{{dir}}/dy, {pt_label}",
    100, 7.0, 2e3,
    100, 1e-5, 20.0
)
frame.SetStats(0)

Format_Hist_total(frame, title_x="dN_{ch}/d#eta",  title_y="dN_{#gamma}^{dir}/dy", left=0.15, bottom=0.15, right=0.01, top=0.01,  Tsize=0.06,  Lsize=0.06,\
                      Mstyle=21,  Msize=1.2, Mcolor=4,  Lwidth=3,  Lcolor=4,  offset_x=1.2, offset_y=1.2, title="",  Malpha=0.5,  Lalpha=1)
frame.Draw()

# Draw systematic boxes first
for item in ref_graphs:
    item["syst"].Draw("2 same")

# Draw stat markers second
for item in ref_graphs:
    item["stat"].Draw("P same")

#new auau 
# Extra PPG Au+Au 200 systematic boxes
g_auau_ppg_syst.Draw("2 same")
g_auau_ppg_stat.Draw("P same")

# Your MB syst
g_mb_syst.SetFillColorAlpha(root.kBlack, 0.60)
g_mb_syst.SetLineColor(root.kBlack)
g_mb_syst.Draw("2 same")

# Your MB stat
g_mb_stat.SetMarkerStyle(33)
g_mb_stat.SetMarkerSize(3.0)
g_mb_stat.SetMarkerColor(root.kBlack)
g_mb_stat.SetLineColor(root.kBlack)
g_mb_stat.Draw("P same")

# Legend similar to published plot
leg = root.TLegend(0.34, 0.18, 0.8, 0.49)
leg.SetBorderSize(0)
leg.SetFillStyle(0)
leg.SetTextSize(0.050)

# Avoid duplicate legend entries for Au+Au 200 if filled/open are both present
added = set()

leg.AddEntry(g_auau_ppg_stat, "PHENIX Au+Au 200 GeV 2025", "p")

for item in ref_graphs:
    name = item["group"]["name"]
    if name in added:
        continue
    leg.AddEntry(item["stat"], name, "p")
    added.add(name)

#leg.AddEntry(g_mb_syst, "Cu+Au MB syst.", "f")

leg.Draw()

# Optional label like the plot
leg0 = root.TLegend(0.16, 0.76, 0.53, 0.97, f"     Direct #gamma ({pt_label})")
leg0.SetBorderSize(0)
leg0.SetFillStyle(0)
leg0.SetTextSize(0.05)
leg0.AddEntry(g_mb_stat, "0%-93% Cu+Au 200 GeV", "p")

f_scale = root.TF1("f_scale", "[0]*pow(x,[1])", 10.0, 1500.0)
f_scale.SetParameters(1e-4, 1.25)
f_scale.SetLineColor(root.kBlack)
f_scale.SetLineStyle(2)
f_scale.SetLineWidth(2)
f_scale_copy = root.TF1("f_scale_copy", "[0]*pow(x,[1])", 10.0, 1500.0)
f_scale_copy.SetParameters(1e-4, 1.25)
f_scale_copy.SetLineColor(root.kBlack)
f_scale_copy.SetLineStyle(6)
f_scale_copy.SetLineWidth(2)


# Fit using all archive reference points
g_all_fit = root.TGraphErrors(len(Nch_ref))
for i in range(len(Nch_ref)):
    g_all_fit.SetPoint(i, float(Nch_ref[i]), float(Yield_ref[i]))
    g_all_fit.SetPointError(i, 0.0, float(eYield_ref[i]))

g_all_fit.Fit(f_scale, "RQ0")
#f_scale.Draw("same")

g_auau_ppg_stat.Fit(f_scale_copy, "RQ0")
f_scale_copy.Draw("same")
leg0.AddEntry(f_scale_copy, f"#alpha^{{2025}}_{{Au+Au}} = {f_scale_copy.GetParameter(1):.2f}", "l")
#leg0.AddEntry(f_scale_copy, f"#alpha^{{2025}}_{{Au+Au}} = {f_scale_copy.GetParameter(1):.2f} #pm {f_scale_copy.GetParError(1):.2f}", "l")
#leg0.AddEntry(f_scale, f"   #alpha_{{All}} = {f_scale.GetParameter(1):.2f} #pm {f_scale.GetParError(1):.2f}", "l")
leg0.Draw()


leg2 = root.TLegend(0.6, 0.5, 0.8, 0.56,"PRC109 044912")
leg2.SetBorderSize(0)
leg2.SetFillStyle(0)
leg2.SetTextSize(0.040)
leg2.Draw()

g_pp_ncoll_scaled.Draw("L same")
g_pp_ncoll_scaled_band.Draw("3 same")

leg3 = root.TLegend(0.16, 0.24, 0.53, 0.33)
leg3.SetBorderSize(0)
leg3.SetFillStyle(0)
leg3.SetTextSize(0.050)
leg3.AddEntry(g_pp_ncoll_scaled, "N_{coll}#times pp", "fl")
leg3.Draw()

if draw_logo: root.PHENIXTools.DrawPreliminary(0.77, 0.552, 0.20) 

c_dndy_vs_dNch.Draw()

if safe_as_pdf: c_dndy_vs_dNch.SaveAs("output/res/dndy_vs_dNch_pp_logo.pdf")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c_dndy_vs_dNch
# Info in <TCanvas::Print>: pdf file output/res/dndy_vs_dNch_pp_logo.pdf has been created

# %%
pt_label = f"{pt_min:g}<p_{{T}}<{pt_max:g} GeV/c"

c_dndy_vs_dNch = root.TCanvas("c_dndy_vs_dNch", "c_dndy_vs_dNch", 850, 700)
c_dndy_vs_dNch.SetLogy()
c_dndy_vs_dNch.SetLogx()

frame = root.TH2F(
    "frame_dndy_vs_dNch",
    f";dN_{{ch}}/d#eta;dN_{{#gamma}}^{{dir}}/dy, {pt_label}",
    100, 1.0, 2e3,
    100, 1e-4, 20.0
)
frame.SetStats(0)

Format_Hist_total(frame, title_x="dN_{ch}/d#eta",  title_y="dN_{#gamma}^{dir}/dy", left=0.15, bottom=0.15, right=0.01, top=0.01,  Tsize=0.06,  Lsize=0.06,\
                      Mstyle=21,  Msize=1.2, Mcolor=4,  Lwidth=3,  Lcolor=4,  offset_x=1, offset_y=1.2, title="",  Malpha=0.5,  Lalpha=1)
frame.Draw()

# Draw systematic boxes first
for item in ref_graphs:
    item["syst"].Draw("2 same")

# Draw stat markers second
for item in ref_graphs:
    item["stat"].Draw("P same")

#new auau 
# Extra PPG Au+Au 200 systematic boxes
g_auau_ppg_syst.Draw("2 same")
g_auau_ppg_stat.Draw("P same")

# Your MB syst
g_mb_syst.SetFillColorAlpha(root.kMagenta, 0.50)
g_mb_syst.SetLineColor(root.kMagenta)
g_mb_syst.Draw("2 same")

# Your MB stat
g_mb_stat.SetMarkerStyle(33)
g_mb_stat.SetMarkerSize(3.0)
g_mb_stat.SetMarkerColor(root.kMagenta)
g_mb_stat.SetLineColor(root.kMagenta)
g_mb_stat.Draw("P same")

# Legend similar to published plot
leg = root.TLegend(0.55, 0.10, 0.98, 0.48)
leg.SetBorderSize(0)
leg.SetFillStyle(0)
leg.SetTextSize(0.030)

# Avoid duplicate legend entries for Au+Au 200 if filled/open are both present
added = set()
leg.AddEntry(g_auau_ppg_stat, "PHENIX Au+Au 200 GeV, PPG", "p")

for item in ref_graphs:
    name = item["group"]["name"]
    if name in added:
        continue
    leg.AddEntry(item["stat"], name, "p")
    added.add(name)

leg.AddEntry(g_mb_stat, "Cu+Au MB, this analysis", "p")
leg.AddEntry(g_mb_syst, "Cu+Au MB syst.", "f")

leg.Draw()

# Optional label like the plot
leg0 = root.TLegend(0.15, 0.88, 0.58, 0.96, f"Direct #gamma ({pt_label})")
leg0.SetBorderSize(0)
leg0.SetFillStyle(0)
leg0.SetTextSize(0.05)
leg0.Draw()

f_scale = root.TF1("f_scale", "[0]*pow(x,[1])", 5.0, 1500.0)
f_scale.SetParameters(1e-4, 1.25)
f_scale.SetLineColor(root.kBlack)
f_scale.SetLineStyle(2)
f_scale.SetLineWidth(2)

# Fit using all archive reference points
g_all_fit = root.TGraphErrors(len(Nch_ref))
for i in range(len(Nch_ref)):
    g_all_fit.SetPoint(i, float(Nch_ref[i]), float(Yield_ref[i]))
    g_all_fit.SetPointError(i, 0.0, float(eYield_ref[i]))

g_all_fit.Fit(f_scale, "RQ0")
f_scale.Draw("same")

leg1 = root.TLegend(0.63, 0.84, 0.93, 0.94, f"#alpha = {f_scale.GetParameter(1):.2f} #pm {f_scale.GetParError(1):.2f}")
leg1.SetBorderSize(0)
leg1.SetFillStyle(0)
leg1.SetTextSize(0.05)
leg1.Draw()

c_dndy_vs_dNch.Draw()

#if safe_as_pdf: c_dndy_vs_dNch.SaveAs("output/res/dndy_vs_dNch.pdf")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c_dndy_vs_dNch
# <div id="root_plot_1781728329831" style="width: 850px; height: 700px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1781728329831(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.15,"fRightMargin":0.01,"fBottomMargin":0.15,"fTopMargin":0.01,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.589469642082854,"fY1":-4.94661249922571,"fX2":3.3403279693629,"fY2":1.36413749169413,"fXtoAbsPixelk":126.90005007879,"fXtoPixelk":126.90005007879,"fXtoPixel":215.278262049928,"fYtoAbsPixelk":145.26018480766,"fYtoPixelk":145.26018480766,"fYtoPixel":-106.484966282439,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":846,"fVtoAbsPixelk":672.00005,"fVtoPixelk":672,"fVtoPixel":-672,"fAbsPixeltoXk":-0.589469642082854,"fPixeltoXk":-0.589469642082854,"fPixeltoX":0.00464515084095243,"fAbsPixeltoYk":1.36413749169413,"fPixeltoYk":-4.94661249922571,"fPixeltoY":-0.00939099701029739,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":-4,"fUxmax":3.30102999566398,"fUymax":1.30102999566398,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":1,"fTicky":1,"fLogx":1,"fLogy":1,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c_dndy_vs_dNch","fTitle":"c_dndy_vs_dNch","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":16.47059,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":846,"fCh":672,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;110:254,254,254;201:91,91,91;202:122,122,122;203:183,183,183;204:214,214,214;205:137,15,15;206:183,20,20;207:234,71,71;208:239,117 ...

# %%
def make_total_error(stat, syst_down=None, syst_up=None, syst=None):
    if syst is not None:
        return np.sqrt(stat**2 + syst**2)

    if syst_down is not None and syst_up is not None:
        syst_avg = 0.5 * (abs(syst_down) + abs(syst_up))
        return np.sqrt(stat**2 + syst_avg**2)

    return stat


# ------------------------------------------------------------
# Build one combined graph for fitting:
# archive/reference + extra PPG Au+Au + this Cu+Au MB point
# ------------------------------------------------------------

x_fit = []
y_fit = []
ey_fit = []

# 1) Archive/reference points
for i in range(len(Nch_ref)):
    x_fit.append(float(Nch_ref[i]))
    y_fit.append(float(Yield_ref[i]))

    # use total uncertainty for fit
    ey = make_total_error(
        float(eYield_ref[i]),
        syst=float(sYield_ref[i])
    )
    ey_fit.append(float(ey))


# 2) Extra Au+Au PPG points
for i in range(len(dNch_auau_ppg)):
    x_fit.append(float(dNch_auau_ppg[i]))
    y_fit.append(float(y_auau_ppg[i]))

    ey = make_total_error(
        float(y_auau_ppg_stat[i]),
        syst=float(y_auau_ppg_syst[i])
    )
    ey_fit.append(float(ey))


# 3) This Cu+Au MB point
x_fit.append(float(dNch_mb))
y_fit.append(float(dndy_mb))

ey_mb = make_total_error(
    float(dndy_mb_stat),
    syst_down=float(dndy_mb_syst_down),
    syst_up=float(dndy_mb_syst_up)
)
ey_fit.append(float(ey_mb))


x_fit = np.array(x_fit)
y_fit = np.array(y_fit)
ey_fit = np.array(ey_fit)

# remove bad points
mask_fit = (
    np.isfinite(x_fit) &
    np.isfinite(y_fit) &
    np.isfinite(ey_fit) &
    (x_fit > 0) &
    (y_fit > 0) &
    (ey_fit > 0)
)

x_fit = x_fit[mask_fit]
y_fit = y_fit[mask_fit]
ey_fit = ey_fit[mask_fit]


g_all_fit_with_cuau = root.TGraphErrors(len(x_fit))

for i in range(len(x_fit)):
    g_all_fit_with_cuau.SetPoint(i, float(x_fit[i]), float(y_fit[i]))
    g_all_fit_with_cuau.SetPointError(i, 0.0, float(ey_fit[i]))

g_all_fit_with_cuau.SetName("g_all_fit_with_cuau")

# %%
pt_label = f"{pt_min:g}<p_{{T}}<{pt_max:g} GeV/c"

c_dndy_vs_dNch = root.TCanvas("c_dndy_vs_dNch", "c_dndy_vs_dNch", 850, 700)
c_dndy_vs_dNch.SetLogy()
c_dndy_vs_dNch.SetLogx()

frame = root.TH2F(
    "frame_dndy_vs_dNch",
    f";dN_{{ch}}/d#eta;dN_{{#gamma}}^{{dir}}/dy, {pt_label}",
    100, 1.0, 2e3,
    100, 1e-4, 20.0
)
frame.SetStats(0)
frame.Draw()

# Draw systematic boxes first
for item in ref_graphs:
    item["syst"].Draw("2 same")

# Draw stat markers second
for item in ref_graphs:
    item["stat"].Draw("P same")

#new auau 
# Extra PPG Au+Au 200 systematic boxes
g_auau_ppg_syst.Draw("2 same")
g_auau_ppg_stat.Draw("P same")

# Your MB syst
g_mb_syst.SetFillColorAlpha(root.kMagenta, 0.50)
g_mb_syst.SetLineColor(root.kMagenta)
g_mb_syst.Draw("2 same")

# Your MB stat
g_mb_stat.SetMarkerStyle(33)
g_mb_stat.SetMarkerSize(3.0)
g_mb_stat.SetMarkerColor(root.kMagenta)
g_mb_stat.SetLineColor(root.kMagenta)
g_mb_stat.Draw("P same")

# Legend similar to published plot
leg = root.TLegend(0.15, 0.60, 0.58, 0.88)
leg.SetBorderSize(0)
leg.SetFillStyle(0)
leg.SetTextSize(0.030)

# Avoid duplicate legend entries for Au+Au 200 if filled/open are both present
added = set()
leg.AddEntry(g_auau_ppg_stat, "PHENIX Au+Au 200 GeV, PPG", "p")

for item in ref_graphs:
    name = item["group"]["name"]
    if name in added:
        continue
    leg.AddEntry(item["stat"], name, "p")
    added.add(name)

leg.AddEntry(g_mb_stat, "Cu+Au MB, this analysis", "p")
leg.AddEntry(g_mb_syst, "Cu+Au MB syst.", "f")

leg.Draw()

# Optional label like the plot
lat = root.TLatex()
lat.SetNDC(True)
lat.SetTextSize(0.035)
lat.DrawLatex(0.17, 0.88, f"Direct #gamma ({pt_label})")

x_fit = []
y_fit = []
ey_fit = []

# Archive/reference points
for i in range(len(Nch_ref)):
    x_fit.append(float(Nch_ref[i]))
    y_fit.append(float(Yield_ref[i]))
    ey_fit.append(float(np.sqrt(eYield_ref[i]**2 + 0*sYield_ref[i]**2)))

# Extra Au+Au PPG points
for i in range(len(dNch_auau_ppg)):
    x_fit.append(float(dNch_auau_ppg[i]))
    y_fit.append(float(y_auau_ppg[i]))
    ey_fit.append(float(np.sqrt(y_auau_ppg_stat[i]**2 + 0*y_auau_ppg_syst[i]**2)))

# Your Cu+Au MB point
x_fit.append(float(dNch_mb))
y_fit.append(float(dndy_mb))
ey_fit.append(float(np.sqrt(
    dndy_mb_stat**2 +
    (0.5 * (dndy_mb_syst_down + 0*dndy_mb_syst_up))**2
)))

g_all_fit = root.TGraphErrors(len(x_fit))

for i in range(len(x_fit)):
    g_all_fit.SetPoint(i, x_fit[i], y_fit[i])
    g_all_fit.SetPointError(i, 0.0, ey_fit[i])

f_scale = root.TF1("f_scale", "[0]*pow(x,[1])", 5.0, 1500.0)
f_scale.SetParameters(1e-4, 1.25)
f_scale.SetLineColor(root.kBlack)
f_scale.SetLineStyle(2)
f_scale.SetLineWidth(2)

g_all_fit.Fit(f_scale, "RQ0")
f_scale.Draw("same")

lat.DrawLatex(0.63, 0.24, f"#alpha = {f_scale.GetParameter(1):.2f} #pm {f_scale.GetParError(1):.2f}")

c_dndy_vs_dNch.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c_dndy_vs_dNch
# <div id="root_plot_1781728420154" style="width: 850px; height: 700px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1781728420154(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.15,"fRightMargin":0.01,"fBottomMargin":0.15,"fTopMargin":0.01,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0.406538762219663,"fY1":-6.12518392779714,"fX2":3.330267279035,"fY2":1.37604225285975,"fXtoAbsPixelk":-117.634604127348,"fXtoPixelk":-117.634604127348,"fXtoPixel":289.356551107387,"fYtoAbsPixelk":123.273281822584,"fYtoPixelk":123.273281822584,"fYtoPixel":-89.5853536229663,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":846,"fVtoAbsPixelk":672.00005,"fVtoPixelk":672,"fVtoPixel":-672,"fAbsPixeltoXk":0.406538762219663,"fPixeltoXk":0.406538762219663,"fPixeltoX":0.00345594387330418,"fAbsPixeltoYk":1.37604225285975,"fPixeltoYk":-6.12518392779714,"fPixeltoY":-0.0111625389593108,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0.845098040014257,"fUymin":-5,"fUxmax":3.30102999566398,"fUymax":1.30102999566398,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":1,"fTicky":1,"fLogx":1,"fLogy":1,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c_dndy_vs_dNch","fTitle":"c_dndy_vs_dNch","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":16.47059,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":846,"fCh":672,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;110:254,254,254;201:91,91,91;202:122,122,122;203:183,183,183;204:214,214,214;205:137,15,15;206:183,20,20;207:234, ...
