# %%
import ROOT as root
from array import array
root.gErrorIgnoreLevel = root.kFatal
# %jsroot on
root.gStyle.SetOptStat(0)
# Out:
# Welcome to JupyROOT 6.30/06

# %%
colors=[1,2,4,root.kGreen+2,root.kOrange+4,root.kMagenta,root.kGray,root.kGray,root.kBlack,root.kCyan,root.kOrange,root.kViolet,root.kCyan,root.kGreen,root.kOrange]
file_path="./"
file_names=["dzed.root","graph.root"]#,"m_ee_DCA_535.root"],"m_ee_DCA_536.root"]
ee_hist_names=["cent4","gr_ratio_default"]
hist_names = [ee_hist_names]

# %%
hists_read = []

for iFile in range(len(file_names)):
    infile = root.TFile.Open(file_path + file_names[iFile], "read")
    infile.ls()

    hists_read_file = []

    for itype in range(len(hist_names)):
        hist_read_type = []

        for iname in hist_names[itype]:
            obj = infile.Get(iname)

            if not obj:
                print(f"Could not find {iname} in file {file_names[iFile]}")
                continue

            obj = obj.Clone(f"{obj.GetName()}_file{iFile}")

            # Only histograms have SetDirectory
            if obj.InheritsFrom("TH1"):
                obj.SetDirectory(root.nullptr)

            hist_read_type.append(obj)

        hists_read_file.append(hist_read_type)

    hists_read.append(hists_read_file)
    infile.Close()
# Out:
# Could not find gr_ratio_default in file dzed.root
# Could not find cent4 in file graph.root
# TFile**		./dzed.root
#  TFile*		./dzed.root
#   KEY: TGraphErrors	cent0;1	Graph
#   KEY: TGraphErrors	cent1;1	Graph
#   KEY: TGraphErrors	cent2;1	Graph
#   KEY: TGraphErrors	cent3;1	Graph
#   KEY: TGraphErrors	cent4;1	Graph
# TFile**		./graph.root
#  TFile*		./graph.root
#   KEY: TGraphErrors	gr_ratio_default;1
#   KEY: TGraphErrors	gr_ratio_tight;1
#   KEY: TGraphErrors	gr_ratio_verytight;1
#   KEY: TCanvas	c_ratio_allcuts;1

# %%
iFile=0
itype=0
print(f"Number of hists in type {itype}: {len(hists_read[iFile][itype])}")
c1 = root.TCanvas("c1","c1",1400,800)
hists_read[iFile][itype][0].Draw("")

c1.Draw()
# Out:
# Number of hists in type 0: 1
# <div id="root_plot_1780014956927" style="width: 1400px; height: 800px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1780014956927(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.250000051409009,"fY1":1.74975039595343,"fX2":6.65000005140901,"fY2":11.7484374815014,"fXtoAbsPixelk":50.5797697922421,"fXtoPixelk":50.5797697922421,"fXtoPixel":202.318837564924,"fYtoAbsPixelk":907.098517840692,"fYtoPixelk":907.098517840692,"fYtoPixel":-77.2101370304748,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":1396,"fVtoAbsPixelk":772.00005,"fVtoPixelk":772,"fVtoPixel":-772,"fAbsPixeltoXk":-0.250000051409009,"fPixeltoXk":-0.250000051409009,"fPixeltoX":0.004942693483394,"fAbsPixeltoYk":11.7484374815014,"fPixeltoYk":1.74975039595343,"fPixeltoY":-0.0129516672092591,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0.44,"fUymin":2.74961916410505,"fUxmax":5.96,"fUymax":10.7485687133498,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c1","fTitle":"c1","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":11.42857,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":1396,"fCh":772,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;110:254,254,254;201:91,91,91;202:122,122,122;203:183,183,183;204:214,214,214;205:137,15,15;206:183,20,20;207:234,71,71;208:239,117,117;209:15,137,15;21 ...

# %%
import numpy as np

pt_orange = np.array([
    0.898, 1.105, 1.302, 1.504, 1.705, 1.905,
    2.253, 2.753, 3.251, 3.752, 4.500, 5.998, 8.496
])

eff_orange = np.array([
    0.0855, 0.0964, 0.1061, 0.1171, 0.1270, 0.1407,
    0.1563, 0.1836, 0.2112, 0.2335, 0.2668, 0.3169, 0.3744
])

graph_wenqing = root.TGraph(len(pt_orange), array('d', pt_orange), array('d', eff_orange))

# %%
iFile=1
itype=0
print(f"Number of hists in type {itype}: {len(hists_read[iFile][itype])}")
c1 = root.TCanvas("c1","c1",1400,800)
hists_read[iFile][itype][0].Draw("")
print(hists_read[iFile][itype][0].Eval(1.5))
graph_wenqing.SetMarkerStyle(20)
graph_wenqing.SetMarkerColor(root.kRed)
graph_wenqing.Draw("P SAME")

c1.Draw()
# Out:
# Number of hists in type 0: 1
# 0.12003089494018478
# <div id="root_plot_1780014957154" style="width: 1400px; height: 800px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1780014957154(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.500000089406973,"fY1":0.0624839226575503,"fX2":11.500000089407,"fY2":0.367428070037542,"fXtoAbsPixelk":58.1667262009267,"fXtoPixelk":58.1667262009267,"fXtoPixel":116.333331599831,"fYtoAbsPixelk":930.185044550887,"fYtoPixelk":930.185044550887,"fYtoPixel":-2531.61113808165,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":1396,"fVtoAbsPixelk":772.00005,"fVtoPixelk":772,"fVtoPixel":-772,"fAbsPixeltoXk":-0.500000089406973,"fPixeltoXk":-0.500000089406973,"fPixeltoX":0.00859598866677217,"fAbsPixeltoYk":0.367428070037542,"fPixeltoYk":0.0624839226575503,"fPixeltoY":-3.95005372253875e-4,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0.7,"fUymin":0.0929783392131583,"fUxmax":10.3,"fUymax":0.336933653481934,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c1","fTitle":"c1","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":11.42857,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":1396,"fCh":772,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;110:254,254,254;201:91,91,91;202:122,122,122;203:183,183,183;204:214,214,214;205:137,15,15;206:183,20,20;207:234,71,71;208:239,117,117;209:15 ...

# %%
import numpy as np

# Cu+Au @ 200 GeV, 0-20%
# ratio = gamma_hadron / gamma_pi0

pt_ratio = np.array([
    0.55, 0.60, 0.70, 0.80, 0.90, 1.00,
    1.25, 1.50, 1.75, 2.00, 2.25, 2.50,
    2.75, 3.00, 3.50, 4.00, 4.50, 5.00,
    5.50, 6.00, 6.50, 7.00, 7.50, 8.00,
    8.50, 9.00, 9.50, 9.90
])

ratio_vals = np.array([
    1.09696, 1.11315, 1.13620, 1.14979, 1.15773, 1.16320,
    1.17504, 1.18419, 1.19127, 1.19712, 1.20184, 1.20584,
    1.20926, 1.21221, 1.21708, 1.22092, 1.22365, 1.22579,
    1.22739, 1.22838, 1.22922, 1.22976, 1.22995, 1.23024,
    1.23024, 1.23028, 1.22996, 1.22980
])

def gamma_hadron_over_gamma_pi0(pt):
    return np.interp(pt, pt_ratio, ratio_vals)

# %%
embed = [ 0.713, 0.899, 0.937, 0.914, 0.881, 0.897, 0.886, 0.920, 0.919 ]
pt_embed = [ 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5 ]
embed_graph = root.TGraph(len(pt_embed), array('d', pt_embed), array('d', embed))
print(embed_graph.Eval(3.5))
# Out:
# 0.937

# %%
import numpy as np

pt_wenq = [0.9, 1.1, 1.3, 1.5, 1.7, 1.9, 2.25, 2.75, 3.25, 3.75, 4.5, 6.0, 8.5]
pt_err = [0.05] * len(pt_wenq)  # Assuming a constant error of 0.1 GeV/c for all points

rgamma_50_60 = [1.117, 1.145, 1.114, 1.144, 1.149, 1.138, 1.164, 1.159, 1.203, 1.182, 1.276, 1.202, 1.816]

stat_50_60 = [0.016, 0.019, 0.012, 0.013, 0.015, 0.017, 0.014, 0.022, 0.033, 0.047, 0.051, 0.072, 0.297]

syst_50_60 = [0.054, 0.055, 0.053, 0.055, 0.055, 0.054, 0.054, 0.053, 0.054, 0.052, 0.053, 0.050, 0.074]

graph_wenqing_rg = root.TGraphErrors(len(pt_wenq), array('d', pt_wenq), array('d', rgamma_50_60), array('d', pt_err), array('d', syst_50_60))

# %%
inc_over_tag_ratio = hists_read[0][0][0]  #Tgraph from file
epsilon_f = hists_read[1][0][0] 
rgamma_graph = root.TGraphErrors(len(pt_ratio))
for ipoint in range(inc_over_tag_ratio.GetN()):
    pt = inc_over_tag_ratio.GetX()[ipoint]
    ratio = inc_over_tag_ratio.GetY()[ipoint]
    ratio_err = inc_over_tag_ratio.GetEY()[ipoint]
    rgamma_val = 1.*ratio / gamma_hadron_over_gamma_pi0(pt) * epsilon_f.Eval(pt) * 0.9 #* embed_graph.Eval(pt)
    print(f"pt: {pt:.2f}, ratio: {ratio:.3f}, gamma_hadron_over_gamma_pi0: {gamma_hadron_over_gamma_pi0(pt):.3f}, embed: {embed_graph.Eval(pt):.3f}, epsilon_f: {epsilon_f.Eval(pt):.3f}, R_gamma: {rgamma_val:.3f}")
    rgamma_err= rgamma_val * ratio_err / ratio
    rgamma_graph.SetPoint(ipoint, pt, rgamma_val)
    rgamma_graph.SetPointError(ipoint, 0, rgamma_err)

c2 = root.TCanvas("c2","c2",1400,800)
rgamma_graph.SetMarkerStyle(20)
rgamma_graph.SetMarkerColor(root.kRed)
rgamma_graph.SetTitle("R_gamma vs pT; pT (GeV/c); R_gamma")
rgamma_graph.Draw("AP")
graph_wenqing_rg.SetMarkerStyle(20)
graph_wenqing_rg.SetMarkerColor(root.kBlue)
graph_wenqing_rg.Draw("P SAME")
c2.Draw()
# Out:
# pt: 0.90, ratio: 10.045, gamma_hadron_over_gamma_pi0: 1.158, embed: 0.601, epsilon_f: 0.083, R_gamma: 0.645
# pt: 1.25, ratio: 7.671, gamma_hadron_over_gamma_pi0: 1.175, embed: 0.666, epsilon_f: 0.104, R_gamma: 0.614
# pt: 1.75, ratio: 6.614, gamma_hadron_over_gamma_pi0: 1.191, embed: 0.759, epsilon_f: 0.136, R_gamma: 0.678
# pt: 2.25, ratio: 5.909, gamma_hadron_over_gamma_pi0: 1.202, embed: 0.853, epsilon_f: 0.167, R_gamma: 0.738
# pt: 2.75, ratio: 5.190, gamma_hadron_over_gamma_pi0: 1.209, embed: 0.909, epsilon_f: 0.194, R_gamma: 0.749
# pt: 3.25, ratio: 4.948, gamma_hadron_over_gamma_pi0: 1.215, embed: 0.927, epsilon_f: 0.217, R_gamma: 0.795
# pt: 3.75, ratio: 5.170, gamma_hadron_over_gamma_pi0: 1.219, embed: 0.931, epsilon_f: 0.240, R_gamma: 0.915
# pt: 4.50, ratio: 5.056, gamma_hadron_over_gamma_pi0: 1.224, embed: 0.914, epsilon_f: 0.274, R_gamma: 1.018
# pt: 5.50, ratio: 3.888, gamma_hadron_over_gamma_pi0: 1.227, embed: 0.881, epsilon_f: 0.292, R_gamma: 0.832
# <div id="root_plot_1780014957591" style="width: 1400px; height: 800px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1780014957591(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.756250056345019,"fY1":-0.151200109914264,"fX2":6.80625005634502,"fY2":1.36080089910609,"fXtoAbsPixelk":139.600058320809,"fXtoPixelk":139.600058320809,"fXtoPixel":184.595038571633,"fYtoAbsPixelk":694.800045398521,"fYtoPixelk":694.800045398521,"fYtoPixel":-510.581669849672,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":1396,"fVtoAbsPixelk":772.00005,"fVtoPixelk":772,"fVtoPixel":-772,"fAbsPixeltoXk":-0.756250056345019,"fPixeltoXk":-0.756250056345019,"fPixeltoX":0.00541726369103871,"fAbsPixeltoYk":1.36080089910609,"fPixeltoYk":-0.151200109914264,"fPixeltoY":-0.00195855052981911,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":6.05,"fUymax":1.20960078919182,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c2","fTitle":"c2","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":11.42857,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":1396,"fCh":772,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;110:254,254,254;201:91,91,91;202:122,122,122;203:183,183,183;204:214,214,214;205:137,15,15;206:183,20,20;207:234,71,71;208:239,117,117;209:15,137,15;210:20,183,20 ...

# %%
epsf_mb = [ 0.101, 0.174, 0.224, 0.311, 0.355, 0.402, 0.396, 0.421, 0.371, 0.326 ]
pt_embed = [0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5 ]
epsf_graph = root.TGraph(len(pt_embed), array('d', pt_embed), array('d', epsf_mb))
print(epsf_graph.Eval(0.9))
# Out:
# 0.1302

# %%
inc_over_tag_ratio = hists_read[0][0][0]  #Tgraph from file
epsilon_f = hists_read[1][0][0] 
rgamma_graph_my = root.TGraphErrors(len(pt_ratio))
for ipoint in range(inc_over_tag_ratio.GetN()):
    pt = inc_over_tag_ratio.GetX()[ipoint]
    ratio = inc_over_tag_ratio.GetY()[ipoint]
    ratio_err = inc_over_tag_ratio.GetEY()[ipoint]
    rgamma_val = ratio / gamma_hadron_over_gamma_pi0(pt) * epsf_graph.Eval(pt) #* embed_graph.Eval(pt)
    print(f"pt: {pt:.2f}, ratio: {ratio:.3f}, gamma_hadron_over_gamma_pi0: {gamma_hadron_over_gamma_pi0(pt):.3f}, epsilon_f: {epsf_graph.Eval(pt):.3f}, R_gamma: {rgamma_val:.3f}")
    rgamma_err= rgamma_val * ratio_err / ratio
    rgamma_graph_my.SetPoint(ipoint, pt, rgamma_val)
    rgamma_graph_my.SetPointError(ipoint, 0, rgamma_err)

c2 = root.TCanvas("c2","c2",1400,800)
rgamma_graph_my.SetMarkerStyle(20)
rgamma_graph_my.SetMarkerColor(root.kRed)
rgamma_graph_my.SetTitle(";p_{T} (GeV/c); R_{#gamma}")
rgamma_graph_my.Draw("AP")
rgamma_graph_my.GetYaxis().SetRangeUser(0.5, 1.5)

rgamma_graph_my.GetXaxis().SetTitleOffset(1.1)
rgamma_graph_my.GetXaxis().SetTitleSize(0.06)
rgamma_graph_my.GetXaxis().SetLabelSize(0.05)
rgamma_graph_my.GetYaxis().SetTitleOffset(1.2)
rgamma_graph_my.GetYaxis().SetTitleSize(0.06)
rgamma_graph_my.GetYaxis().SetLabelSize(0.05)
c2.SetBottomMargin(0.15)
c2.SetLeftMargin(0.15)
c2.SetRightMargin(0.03)
c2.SetTopMargin(0.03)



graph_wenqing_rg.SetLineWidth(2)

graph_wenqing_rg.SetFillColorAlpha(root.kBlue, 0.5)
graph_wenqing_rg.SetFillStyle(1001)
graph_wenqing_rg.Draw("2P SAME")
c2.Draw()
# Out:
# pt: 0.90, ratio: 10.045, gamma_hadron_over_gamma_pi0: 1.158, epsilon_f: 0.130, R_gamma: 1.130
# pt: 1.25, ratio: 7.671, gamma_hadron_over_gamma_pi0: 1.175, epsilon_f: 0.156, R_gamma: 1.017
# pt: 1.75, ratio: 6.614, gamma_hadron_over_gamma_pi0: 1.191, epsilon_f: 0.186, R_gamma: 1.035
# pt: 2.25, ratio: 5.909, gamma_hadron_over_gamma_pi0: 1.202, epsilon_f: 0.211, R_gamma: 1.040
# pt: 2.75, ratio: 5.190, gamma_hadron_over_gamma_pi0: 1.209, epsilon_f: 0.246, R_gamma: 1.055
# pt: 3.25, ratio: 4.948, gamma_hadron_over_gamma_pi0: 1.215, epsilon_f: 0.289, R_gamma: 1.178
# pt: 3.75, ratio: 5.170, gamma_hadron_over_gamma_pi0: 1.219, epsilon_f: 0.322, R_gamma: 1.366
# pt: 4.50, ratio: 5.056, gamma_hadron_over_gamma_pi0: 1.224, epsilon_f: 0.355, R_gamma: 1.467
# pt: 5.50, ratio: 3.888, gamma_hadron_over_gamma_pi0: 1.227, epsilon_f: 0.402, R_gamma: 1.273
# <div id="root_plot_1780015305614" style="width: 1400px; height: 800px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1780015305614(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.15,"fRightMargin":0.03,"fBottomMargin":0.15,"fTopMargin":0.03,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-1.10670729025817,"fY1":0.317073175163938,"fX2":6.27134144430895,"fY2":1.53658536269569,"fXtoAbsPixelk":209.400046229634,"fXtoPixelk":209.400046229634,"fXtoPixel":189.209918533007,"fYtoAbsPixelk":972.720054055053,"fYtoPixelk":972.720054055053,"fYtoPixel":-633.040003940016,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":1396,"fVtoAbsPixelk":772.00005,"fVtoPixelk":772,"fVtoPixel":-772,"fAbsPixeltoXk":-1.10670729025817,"fPixeltoXk":-1.10670729025817,"fPixeltoX":0.00528513519668132,"fAbsPixeltoYk":1.53658536269569,"fPixeltoYk":0.317073175163938,"fPixeltoY":-0.00157967899939347,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0.5,"fUxmax":6.05,"fUymax":1.5,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c2","fTitle":"c2","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":11.42857,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":1396,"fCh":772,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;110:254,254,254;201:91,91,91;202:122,122,122;203:183,183,183;204:214,214,214;205:137,15,15;206:183,20,20;207:234,71,71;208:239,117,117;209:15,137,15;210:20,183,20;211:71,234, ...
